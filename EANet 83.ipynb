# %%
# !pip install tensorflow-addons
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import zipfile
from PIL import Image
from tensorflow.keras.utils import to_categorical

# Define the path to your zip file containing the dataset
zip_file_path = '/content/drive/MyDrive/CSE400 Thesis/Pothole Dataset 10000.zip'

# Define the directory where you want to extract the dataset
extracted_path = '/Downloads/FINAL_DATASET_TTTTTT'

# Create the directory for extracted data
os.makedirs(extracted_path, exist_ok=True)

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

# %%
train_path = "/Downloads/FINAL_DATASET_TTTTTT/train"
test_path = "/Downloads/FINAL_DATASET_TTTTTT/test"
x_train=[]

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
# !pip install -U -q tensorflow-addons
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
num_classes  = 2
input_shape  = (128, 128, 3)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (8000, 128, 128, 3) - y_train shape: (8000, 2)
# x_test shape: (2000, 128, 128, 3) - y_test shape: (2000, 2)

# %%
weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
validation_split = 0.2
batch_size = 32
num_epochs = 50
patch_size = 2  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2
num_transformer_blocks = 8  # Number of repetitions of the transformer layer

print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
# Out:
# Patch size: 2 X 2 = 4
# Patches per image: 4096

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.1),
        layers.RandomContrast(factor=0.1),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %%
def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %%
def get_model(attention_type="external_attention"):
    inputs = layers.Input(shape=input_shape)
    # Image augment
    x = data_augmentation(inputs)
    # Extract patches.
    x = PatchExtract(patch_size)(x)
    # Create patch embedding.
    x = PatchEmbedding(num_patches, embedding_dim)(x)
    # Create Transformer block.
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(
            x,
            embedding_dim,
            mlp_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
            attention_type,
        )

    x = layers.GlobalAvgPool1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = get_model(attention_type="external_attention")

model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
)

loss, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# Epoch 1/50
# 200/200 [==============================] - 181s 862ms/step - loss: 0.6660 - accuracy: 0.6905 - top-5-accuracy: 1.0000 - val_loss: 1.3694 - val_accuracy: 0.4863 - val_top-5-accuracy: 1.0000
# Epoch 2/50
# 200/200 [==============================] - 181s 906ms/step - loss: 0.5036 - accuracy: 0.8012 - top-5-accuracy: 1.0000 - val_loss: 1.2943 - val_accuracy: 0.6031 - val_top-5-accuracy: 1.0000
# Epoch 3/50
# 200/200 [==============================] - 175s 876ms/step - loss: 0.4558 - accuracy: 0.8327 - top-5-accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.6438 - val_top-5-accuracy: 1.0000
# Epoch 4/50
# Epoch 47/50
# 200/200 [==============================] - 175s 875ms/step - loss: 0.2991 - accuracy: 0.9381 - top-5-accuracy: 1.0000 - val_loss: 0.3492 - val_accuracy: 0.9225 - val_top-5-accuracy: 1.0000
# Epoch 48/50
# 200/200 [==============================] - 181s 906ms/step - loss: 0.3035 - accuracy: 0.9336 - top-5-accuracy: 1.0000 - val_loss: 0.4267 - val_accuracy: 0.8975 - val_top-5-accuracy: 1.0000
# Epoch 49/50
# 200/200 [==============================] - 175s 875ms/step - loss: 0.2996 - accuracy: 0.9398 - top-5-accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9463 - val_top-5-accuracy: 1.0000
# Epoch 50/50
# 200/200 [==============================] - 181s 907ms/step - loss: 0.3018 - accuracy: 0.9342 - top-5-accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.8681 - val_top-5-accuracy: 1.0000
# 63/63 [==============================] - 21s 295ms/step - loss: 0.5614 - accuracy: 0.8325 - top-5-accuracy: 1.0000
# Test loss: 0.56
# Test accuracy: 83.25%
# Test top 5 accuracy: 100.0%

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
mpl.rcParams["figure.dpi"] = 300
plt.legend(['Train', 'Validation'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
plt.figure(1)
import matplotlib as mpl
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
mpl.rcParams["figure.dpi"] = 300
plt.legend(['Train', 'Validation'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
import pathlib
import tensorflow as tf


data_dir = pathlib.Path('/Downloads/FINAL_DATASET_TTTTTT/train')

img_height=128
img_width=128


train_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 6400 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)

normalization_layer = tf.keras.layers.Rescaling(1./255)


import numpy as np
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 1600 files for validation.
# 0.04509804 0.959804

# %%
train_label = np.concatenate([y for x, y in train_ds], axis=0)
print(train_label.shape)

test_label = np.concatenate([y for x, y in val_ds], axis=0)
print(test_label.shape)
# Out:
# (6400,)
# (1600,)

# %%
import scipy
# if this works
from scipy.sparse import issparse

# %%
# !pip install scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
#Confution Matrix and Classification Report
import matplotlib.pyplot as plt
Y_pred = model.predict_generator(val_ds, 127)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_label, y_pred)
print(cm)
print('Classification Report')
target_names = ['normal', 'pothole']
print(classification_report(test_label, y_pred, target_names=target_names))
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# <ipython-input-79-2385cd82f669>:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model.predict_generator(val_ds, 127)
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 127 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[149 671]
#  [477 303]]
# Classification Report
#               precision    recall  f1-score   support
#
#       normal       0.24      0.18      0.21       820
#      pothole       0.31      0.39      0.35       780
#
#     accuracy                           0.28      1600
#    macro avg       0.27      0.29      0.28      1600
# weighted avg       0.27      0.28      0.27      1600

# %%
# !pip install seaborn
import seaborn as sns
ax=sns.heatmap(cm, annot=True, cmap='YlGn', cbar=False, linewidths=2, linecolor='y', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
#sns.heatmap(cm, annot=True,annot_kws={"size": 22})
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 300
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
# ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nActual Values')
ax.set_ylabel('Predicted Values ');
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 32, 32, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patch_extract (PatchExtrac  (None, 256, 12)              0         ['data_augmentation[0][0]']
#  t)
#
#  patch_embedding (PatchEmbe  (None, 256, 64)              17216     ['patch_extract[0][0]']
#  dding)
#
#  layer_normalization (Layer  (None, 256, 64)              128       ['patch_embedding[0][0]']
#  Normalization)
#
#  dense_1 (Dense)             (None, 256, 256)             16640     ['layer_normalization[0][0]']
#
#  tf.reshape (TFOpLambda)     (None, 256, 16, 16)          0         ['dense_1[0][0]']
#
#  tf.compat.v1.transpose (TF  (None, 16, 256, 16)          0         ['tf.reshape[0][0]']
#  OpLambda)
#
#  dense_2 (Dense)             (None, 16, 256, 16)          272       ['tf.compat.v1.transpose[0][0]
#                                                                     ']
#
#  softmax (Softmax)           (None, 16, 256, 16)          0         ['dense_2[0][0]']
#
#  tf.math.reduce_sum (TFOpLa  (None, 16, 256, 1)           0         ['softmax[0][0]']
#  mbda)
#
#  tf.__operators__.add (TFOp  (None, 16, 256, 1)           0         ['tf.math.reduce_sum[0][0]']
#  Lambda)
#
#  tf.math.truediv (TFOpLambd  (None, 16, 256, 16)          0         ['softmax[0][0]',
#  a)                                                                  'tf.__operators__.add[0][0]']
#
#  dropout (Dropout)           (None, 16, 256, 16)          0         ['tf.math.truediv[0][0]']
#
#  dense_3 (Dense)             (None, 16, 256, 16)          272       ['dropout[0][0]']
#
#  tf.compat.v1.transpose_1 (  (None, 256, 16, 16)          0         ['dense_3[0][0]']
#  TFOpLambda)
#
#  tf.reshape_1 (TFOpLambda)   (None, 256, 256)             0         ['tf.compat.v1.transpose_1[0][
#                                                                     0]']
#
#  dense_4 (Dense)             (None, 256, 64)              16448     ['tf.reshape_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 256, 64)              0         ['dense_4[0][0]']
#
#  add (Add)                   (None, 256, 64)              0         ['dropout_1[0][0]',
#                                                                      'patch_embedding[0][0]']
#
#  layer_normalization_1 (Lay  (None, 256, 64)              128       ['add[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 256, 64)              4160      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 256, 64)              0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 256, 64)              4160      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 256, 64)              0         ['dense_6[0][0]']
#
#  add_1 (Add)                 (None, 256, 64)              0         ['dropout_3[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 256, 64)              128       ['add_1[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 256, 256)             16640     ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  tf.reshape_2 (TFOpLambda)   (None, 256, 16, 16)          0         ['dense_7[0][0]']
#
#  tf.compat.v1.transpose_2 (  (None, 16, 256, 16)          0         ['tf.reshape_2[0][0]']
#  TFOpLambda)
#
#  dense_8 (Dense)             (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_2[0][
#                                                                     0]']
#
#  softmax_1 (Softmax)         (None, 16, 256, 16)          0         ['dense_8[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None, 16, 256, 1)           0         ['softmax_1[0][0]']
#  Lambda)
#
#  tf.__operators__.add_1 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_1[0][0]']
#  OpLambda)
#
#  tf.math.truediv_1 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_1[0][0]',
#  bda)                                                                'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 16, 256, 16)          0         ['tf.math.truediv_1[0][0]']
#
#  dense_9 (Dense)             (None, 16, 256, 16)          272       ['dropout_4[0][0]']
#
#  tf.compat.v1.transpose_3 (  (None, 256, 16, 16)          0         ['dense_9[0][0]']
#  TFOpLambda)
#
#  tf.reshape_3 (TFOpLambda)   (None, 256, 256)             0         ['tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  dense_10 (Dense)            (None, 256, 64)              16448     ['tf.reshape_3[0][0]']
#
#  dropout_5 (Dropout)         (None, 256, 64)              0         ['dense_10[0][0]']
#
#  add_2 (Add)                 (None, 256, 64)              0         ['dropout_5[0][0]',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 256, 64)              128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_11 (Dense)            (None, 256, 64)              4160      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 256, 64)              0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 256, 64)              4160      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 256, 64)              0         ['dense_12[0][0]']
#
#  add_3 (Add)                 (None, 256, 64)              0         ['dropout_7[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 256, 64)              128       ['add_3[0][0]']
#  erNormalization)
#
#  dense_13 (Dense)            (None, 256, 256)             16640     ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  tf.reshape_4 (TFOpLambda)   (None, 256, 16, 16)          0         ['dense_13[0][0]']
#
#  tf.compat.v1.transpose_4 (  (None, 16, 256, 16)          0         ['tf.reshape_4[0][0]']
#  TFOpLambda)
#
#  dense_14 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_4[0][
#                                                                     0]']
#
#  softmax_2 (Softmax)         (None, 16, 256, 16)          0         ['dense_14[0][0]']
#
#  tf.math.reduce_sum_2 (TFOp  (None, 16, 256, 1)           0         ['softmax_2[0][0]']
#  Lambda)
#
#  tf.__operators__.add_2 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_2[0][0]']
#  OpLambda)
#
#  tf.math.truediv_2 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_2[0][0]',
#  bda)                                                                'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 16, 256, 16)          0         ['tf.math.truediv_2[0][0]']
#
#  dense_15 (Dense)            (None, 16, 256, 16)          272       ['dropout_8[0][0]']
#
#  tf.compat.v1.transpose_5 (  (None, 256, 16, 16)          0         ['dense_15[0][0]']
#  TFOpLambda)
#
#  tf.reshape_5 (TFOpLambda)   (None, 256, 256)             0         ['tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  dense_16 (Dense)            (None, 256, 64)              16448     ['tf.reshape_5[0][0]']
#
#  dropout_9 (Dropout)         (None, 256, 64)              0         ['dense_16[0][0]']
#
#  add_4 (Add)                 (None, 256, 64)              0         ['dropout_9[0][0]',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 256, 64)              128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_17 (Dense)            (None, 256, 64)              4160      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_10 (Dropout)        (None, 256, 64)              0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 256, 64)              4160      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 256, 64)              0         ['dense_18[0][0]']
#
#  add_5 (Add)                 (None, 256, 64)              0         ['dropout_11[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 256, 64)              128       ['add_5[0][0]']
#  erNormalization)
#
#  dense_19 (Dense)            (None, 256, 256)             16640     ['layer_normalization_6[0][0]'
#                                                                     ]
#
#  tf.reshape_6 (TFOpLambda)   (None, 256, 16, 16)          0         ['dense_19[0][0]']
#
#  tf.compat.v1.transpose_6 (  (None, 16, 256, 16)          0         ['tf.reshape_6[0][0]']
#  TFOpLambda)
#
#  dense_20 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_6[0][
#                                                                     0]']
#
#  softmax_3 (Softmax)         (None, 16, 256, 16)          0         ['dense_20[0][0]']
#
#  tf.math.reduce_sum_3 (TFOp  (None, 16, 256, 1)           0         ['softmax_3[0][0]']
#  Lambda)
#
#  tf.__operators__.add_3 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_3[0][0]']
#  OpLambda)
#
#  tf.math.truediv_3 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_3[0][0]',
#  bda)                                                                'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 16, 256, 16)          0         ['tf.math.truediv_3[0][0]']
#
#  dense_21 (Dense)            (None, 16, 256, 16)          272       ['dropout_12[0][0]']
#
#  tf.compat.v1.transpose_7 (  (None, 256, 16, 16)          0         ['dense_21[0][0]']
#  TFOpLambda)
#
#  tf.reshape_7 (TFOpLambda)   (None, 256, 256)             0         ['tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  dense_22 (Dense)            (None, 256, 64)              16448     ['tf.reshape_7[0][0]']
#
#  dropout_13 (Dropout)        (None, 256, 64)              0         ['dense_22[0][0]']
#
#  add_6 (Add)                 (None, 256, 64)              0         ['dropout_13[0][0]',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 256, 64)              128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_23 (Dense)            (None, 256, 64)              4160      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_14 (Dropout)        (None, 256, 64)              0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 256, 64)              4160      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 256, 64)              0         ['dense_24[0][0]']
#
#  add_7 (Add)                 (None, 256, 64)              0         ['dropout_15[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 256, 64)              128       ['add_7[0][0]']
#  erNormalization)
#
#  dense_25 (Dense)            (None, 256, 256)             16640     ['layer_normalization_8[0][0]'
#                                                                     ]
#
#  tf.reshape_8 (TFOpLambda)   (None, 256, 16, 16)          0         ['dense_25[0][0]']
#
#  tf.compat.v1.transpose_8 (  (None, 16, 256, 16)          0         ['tf.reshape_8[0][0]']
#  TFOpLambda)
#
#  dense_26 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_8[0][
#                                                                     0]']
#
#  softmax_4 (Softmax)         (None, 16, 256, 16)          0         ['dense_26[0][0]']
#
#  tf.math.reduce_sum_4 (TFOp  (None, 16, 256, 1)           0         ['softmax_4[0][0]']
#  Lambda)
#
#  tf.__operators__.add_4 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_4[0][0]']
#  OpLambda)
#
#  tf.math.truediv_4 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_4[0][0]',
#  bda)                                                                'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 16, 256, 16)          0         ['tf.math.truediv_4[0][0]']
#
#  dense_27 (Dense)            (None, 16, 256, 16)          272       ['dropout_16[0][0]']
#
#  tf.compat.v1.transpose_9 (  (None, 256, 16, 16)          0         ['dense_27[0][0]']
#  TFOpLambda)
#
#  tf.reshape_9 (TFOpLambda)   (None, 256, 256)             0         ['tf.compat.v1.transpose_9[0][
#                                                                     0]']
#
#  dense_28 (Dense)            (None, 256, 64)              16448     ['tf.reshape_9[0][0]']
#
#  dropout_17 (Dropout)        (None, 256, 64)              0         ['dense_28[0][0]']
#
#  add_8 (Add)                 (None, 256, 64)              0         ['dropout_17[0][0]',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 256, 64)              128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_29 (Dense)            (None, 256, 64)              4160      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_18 (Dropout)        (None, 256, 64)              0         ['dense_29[0][0]']
#
#  dense_30 (Dense)            (None, 256, 64)              4160      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 256, 64)              0         ['dense_30[0][0]']
#
#  add_9 (Add)                 (None, 256, 64)              0         ['dropout_19[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 256, 64)              128       ['add_9[0][0]']
#  yerNormalization)
#
#  dense_31 (Dense)            (None, 256, 256)             16640     ['layer_normalization_10[0][0]
#                                                                     ']
#
#  tf.reshape_10 (TFOpLambda)  (None, 256, 16, 16)          0         ['dense_31[0][0]']
#
#  tf.compat.v1.transpose_10   (None, 16, 256, 16)          0         ['tf.reshape_10[0][0]']
#  (TFOpLambda)
#
#  dense_32 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_10[0]
#                                                                     [0]']
#
#  softmax_5 (Softmax)         (None, 16, 256, 16)          0         ['dense_32[0][0]']
#
#  tf.math.reduce_sum_5 (TFOp  (None, 16, 256, 1)           0         ['softmax_5[0][0]']
#  Lambda)
#
#  tf.__operators__.add_5 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_5[0][0]']
#  OpLambda)
#
#  tf.math.truediv_5 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_5[0][0]',
#  bda)                                                                'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 16, 256, 16)          0         ['tf.math.truediv_5[0][0]']
#
#  dense_33 (Dense)            (None, 16, 256, 16)          272       ['dropout_20[0][0]']
#
#  tf.compat.v1.transpose_11   (None, 256, 16, 16)          0         ['dense_33[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_11 (TFOpLambda)  (None, 256, 256)             0         ['tf.compat.v1.transpose_11[0]
#                                                                     [0]']
#
#  dense_34 (Dense)            (None, 256, 64)              16448     ['tf.reshape_11[0][0]']
#
#  dropout_21 (Dropout)        (None, 256, 64)              0         ['dense_34[0][0]']
#
#  add_10 (Add)                (None, 256, 64)              0         ['dropout_21[0][0]',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 256, 64)              128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_35 (Dense)            (None, 256, 64)              4160      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 256, 64)              0         ['dense_35[0][0]']
#
#  dense_36 (Dense)            (None, 256, 64)              4160      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 256, 64)              0         ['dense_36[0][0]']
#
#  add_11 (Add)                (None, 256, 64)              0         ['dropout_23[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 256, 64)              128       ['add_11[0][0]']
#  yerNormalization)
#
#  dense_37 (Dense)            (None, 256, 256)             16640     ['layer_normalization_12[0][0]
#                                                                     ']
#
#  tf.reshape_12 (TFOpLambda)  (None, 256, 16, 16)          0         ['dense_37[0][0]']
#
#  tf.compat.v1.transpose_12   (None, 16, 256, 16)          0         ['tf.reshape_12[0][0]']
#  (TFOpLambda)
#
#  dense_38 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_12[0]
#                                                                     [0]']
#
#  softmax_6 (Softmax)         (None, 16, 256, 16)          0         ['dense_38[0][0]']
#
#  tf.math.reduce_sum_6 (TFOp  (None, 16, 256, 1)           0         ['softmax_6[0][0]']
#  Lambda)
#
#  tf.__operators__.add_6 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_6[0][0]']
#  OpLambda)
#
#  tf.math.truediv_6 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_6[0][0]',
#  bda)                                                                'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 16, 256, 16)          0         ['tf.math.truediv_6[0][0]']
#
#  dense_39 (Dense)            (None, 16, 256, 16)          272       ['dropout_24[0][0]']
#
#  tf.compat.v1.transpose_13   (None, 256, 16, 16)          0         ['dense_39[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_13 (TFOpLambda)  (None, 256, 256)             0         ['tf.compat.v1.transpose_13[0]
#                                                                     [0]']
#
#  dense_40 (Dense)            (None, 256, 64)              16448     ['tf.reshape_13[0][0]']
#
#  dropout_25 (Dropout)        (None, 256, 64)              0         ['dense_40[0][0]']
#
#  add_12 (Add)                (None, 256, 64)              0         ['dropout_25[0][0]',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 256, 64)              128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_41 (Dense)            (None, 256, 64)              4160      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 256, 64)              0         ['dense_41[0][0]']
#
#  dense_42 (Dense)            (None, 256, 64)              4160      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)        (None, 256, 64)              0         ['dense_42[0][0]']
#
#  add_13 (Add)                (None, 256, 64)              0         ['dropout_27[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 256, 64)              128       ['add_13[0][0]']
#  yerNormalization)
#
#  dense_43 (Dense)            (None, 256, 256)             16640     ['layer_normalization_14[0][0]
#                                                                     ']
#
#  tf.reshape_14 (TFOpLambda)  (None, 256, 16, 16)          0         ['dense_43[0][0]']
#
#  tf.compat.v1.transpose_14   (None, 16, 256, 16)          0         ['tf.reshape_14[0][0]']
#  (TFOpLambda)
#
#  dense_44 (Dense)            (None, 16, 256, 16)          272       ['tf.compat.v1.transpose_14[0]
#                                                                     [0]']
#
#  softmax_7 (Softmax)         (None, 16, 256, 16)          0         ['dense_44[0][0]']
#
#  tf.math.reduce_sum_7 (TFOp  (None, 16, 256, 1)           0         ['softmax_7[0][0]']
#  Lambda)
#
#  tf.__operators__.add_7 (TF  (None, 16, 256, 1)           0         ['tf.math.reduce_sum_7[0][0]']
#  OpLambda)
#
#  tf.math.truediv_7 (TFOpLam  (None, 16, 256, 16)          0         ['softmax_7[0][0]',
#  bda)                                                                'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 16, 256, 16)          0         ['tf.math.truediv_7[0][0]']
#
#  dense_45 (Dense)            (None, 16, 256, 16)          272       ['dropout_28[0][0]']
#
#  tf.compat.v1.transpose_15   (None, 256, 16, 16)          0         ['dense_45[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_15 (TFOpLambda)  (None, 256, 256)             0         ['tf.compat.v1.transpose_15[0]
#                                                                     [0]']
#
#  dense_46 (Dense)            (None, 256, 64)              16448     ['tf.reshape_15[0][0]']
#
#  dropout_29 (Dropout)        (None, 256, 64)              0         ['dense_46[0][0]']
#
#  add_14 (Add)                (None, 256, 64)              0         ['dropout_29[0][0]',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 256, 64)              128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_47 (Dense)            (None, 256, 64)              4160      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 256, 64)              0         ['dense_47[0][0]']
#
#  dense_48 (Dense)            (None, 256, 64)              4160      ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)        (None, 256, 64)              0         ['dense_48[0][0]']
#
#  add_15 (Add)                (None, 256, 64)              0         ['dropout_31[0][0]',
#                                                                      'add_14[0][0]']
#
#  global_average_pooling1d (  (None, 64)                   0         ['add_15[0][0]']
#  GlobalAveragePooling1D)
#
#  dense_49 (Dense)            (None, 2)                    130       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 355017 (1.35 MB)
# Trainable params: 355010 (1.35 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
