# %%
# !pip install tensorflow-addons
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os

import numpy as np

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report
import itertools

# %matplotlib inline

# %%
batch_size = 32  # The default batch size of keras.
num_classes = 2  # Number of class for the dataset
epochs = 100
data_augmentation = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import zipfile
from PIL import Image
from tensorflow.keras.utils import to_categorical

# Define the path to your zip file containing the dataset
zip_file_path = '/content/drive/MyDrive/CSE400 Thesis/Pothole Dataset 10000.zip'

# Define the directory where you want to extract the dataset
extracted_path = '/Downloads/FINAL_DATA'

# Create the directory for extracted data
os.makedirs(extracted_path, exist_ok=True)

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

# %%
train_path = "/Downloads/FINAL_DATA/train"
test_path = "/Downloads/FINAL_DATA/test"
x_train=[]

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
# !pip install -U -q tensorflow-addons
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
num_classes  = 2
input_shape  = (128, 128, 3)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (8000, 128, 128, 3) - y_train shape: (8000, 2)
# x_test shape: (2000, 128, 128, 3) - y_test shape: (2000, 2)

# %%
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (8000, 128, 128, 3)
# y_train shape: (8000, 2)
# 8000 train samples
# 2000 test samples

# %%
model = Sequential()

# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# FLATTERN => DENSE => RELU => DROPOUT
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
#model.add(Dropout(0.5))

# a softmax classifier
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      896
#
#  activation_6 (Activation)   (None, 128, 128, 32)      0
#
#  conv2d_5 (Conv2D)           (None, 126, 126, 32)      9248
#
#  activation_7 (Activation)   (None, 126, 126, 32)      0
#
#  max_pooling2d_2 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 63, 63, 64)        18496
#
#  activation_8 (Activation)   (None, 63, 63, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 64)        36928
#
#  activation_9 (Activation)   (None, 61, 61, 64)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 57600)             0
#
#  dense_2 (Dense)             (None, 512)               29491712
#
#  activation_10 (Activation)  (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
#  activation_11 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 29558306 (112.76 MB)
# Trainable params: 29558306 (112.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = None  # For recording the history of trainning process.

if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                                    epochs=epochs,
                                    validation_data=(x_test, y_test),
                                    workers=4)
# Out:
# Not using data augmentation.
# Epoch 1/100
# 250/250 [==============================] - 13s 47ms/step - loss: 6.4380 - accuracy: 0.7171 - val_loss: 0.2739 - val_accuracy: 0.8780
# Epoch 2/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.3133 - accuracy: 0.8895 - val_loss: 0.2006 - val_accuracy: 0.9270
# Epoch 3/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.2086 - accuracy: 0.9316 - val_loss: 0.1665 - val_accuracy: 0.9440
# Epoch 4/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1950 - accuracy: 0.9501 - val_loss: 0.1878 - val_accuracy: 0.9405
# Epoch 5/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.2841 - accuracy: 0.9670 - val_loss: 0.1933 - val_accuracy: 0.9465
# Epoch 6/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1330 - accuracy: 0.9712 - val_loss: 0.2018 - val_accuracy: 0.9435
# Epoch 7/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0974 - accuracy: 0.9774 - val_loss: 0.1568 - val_accuracy: 0.9580
# Epoch 8/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1138 - accuracy: 0.9800 - val_loss: 0.7347 - val_accuracy: 0.8550
# Epoch 9/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1149 - accuracy: 0.9847 - val_loss: 0.4563 - val_accuracy: 0.9185
# Epoch 10/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1701 - accuracy: 0.9791 - val_loss: 0.7829 - val_accuracy: 0.8830
# Epoch 11/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.0577 - accuracy: 0.9876 - val_loss: 0.2275 - val_accuracy: 0.9640
# Epoch 12/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1111 - accuracy: 0.9865 - val_loss: 0.5028 - val_accuracy: 0.9545
# Epoch 13/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.3666 - accuracy: 0.9824 - val_loss: 0.2888 - val_accuracy: 0.9565
# Epoch 14/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.2505 - accuracy: 0.9855 - val_loss: 0.2851 - val_accuracy: 0.9655
# Epoch 15/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0988 - accuracy: 0.9896 - val_loss: 0.2778 - val_accuracy: 0.9560
# Epoch 16/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1312 - accuracy: 0.9895 - val_loss: 0.2379 - val_accuracy: 0.9630
# Epoch 17/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1273 - accuracy: 0.9906 - val_loss: 0.3247 - val_accuracy: 0.9620
# Epoch 18/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1278 - accuracy: 0.9875 - val_loss: 0.1893 - val_accuracy: 0.9690
# Epoch 19/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.2651 - accuracy: 0.9911 - val_loss: 0.3925 - val_accuracy: 0.9470
# Epoch 20/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0810 - accuracy: 0.9935 - val_loss: 0.4866 - val_accuracy: 0.9575
# Epoch 21/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.1011 - accuracy: 0.9910 - val_loss: 0.3804 - val_accuracy: 0.9600
# Epoch 22/100
# 250/250 [==============================] - 11s 45ms/step - loss: 0.1014 - accuracy: 0.9925 - val_loss: 0.2292 - val_accuracy: 0.9695
# Epoch 23/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0792 - accuracy: 0.9954 - val_loss: 0.2633 - val_accuracy: 0.9695
# Epoch 24/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0981 - accuracy: 0.9926 - val_loss: 0.3486 - val_accuracy: 0.9675
# Epoch 25/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1201 - accuracy: 0.9933 - val_loss: 0.5556 - val_accuracy: 0.9550
# Epoch 26/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1392 - accuracy: 0.9908 - val_loss: 0.2675 - val_accuracy: 0.9685
# Epoch 27/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0470 - accuracy: 0.9965 - val_loss: 0.3296 - val_accuracy: 0.9640
# Epoch 28/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0655 - accuracy: 0.9956 - val_loss: 0.3306 - val_accuracy: 0.9645
# Epoch 29/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0623 - accuracy: 0.9955 - val_loss: 0.4605 - val_accuracy: 0.9600
# Epoch 30/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.2968 - accuracy: 0.9906 - val_loss: 0.4852 - val_accuracy: 0.9665
# Epoch 31/100
# 250/250 [==============================] - 11s 44ms/step - loss: 0.0816 - accuracy: 0.9942 - val_loss: 0.3853 - val_accuracy: 0.9655
# Epoch 32/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1394 - accuracy: 0.9916 - val_loss: 0.3131 - val_accuracy: 0.9735
# Epoch 33/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0421 - accuracy: 0.9966 - val_loss: 0.4562 - val_accuracy: 0.9655
# Epoch 34/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0860 - accuracy: 0.9920 - val_loss: 0.4661 - val_accuracy: 0.9625
# Epoch 35/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1051 - accuracy: 0.9955 - val_loss: 0.5099 - val_accuracy: 0.9705
# Epoch 36/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0743 - accuracy: 0.9944 - val_loss: 0.4128 - val_accuracy: 0.9690
# Epoch 37/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0428 - accuracy: 0.9965 - val_loss: 0.5135 - val_accuracy: 0.9595
# Epoch 38/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0704 - accuracy: 0.9951 - val_loss: 0.7194 - val_accuracy: 0.9610
# Epoch 39/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0746 - accuracy: 0.9927 - val_loss: 0.6206 - val_accuracy: 0.9610
# Epoch 40/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0884 - accuracy: 0.9950 - val_loss: 0.8801 - val_accuracy: 0.9425
# Epoch 41/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0681 - accuracy: 0.9966 - val_loss: 0.5395 - val_accuracy: 0.9650
# Epoch 42/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0526 - accuracy: 0.9958 - val_loss: 0.7198 - val_accuracy: 0.9590
# Epoch 43/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0809 - accuracy: 0.9952 - val_loss: 0.8765 - val_accuracy: 0.9565
# Epoch 44/100
# 250/250 [==============================] - 11s 42ms/step - loss: 0.0701 - accuracy: 0.9950 - val_loss: 0.9039 - val_accuracy: 0.9550
# Epoch 45/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0207 - accuracy: 0.9986 - val_loss: 0.5982 - val_accuracy: 0.9695
# Epoch 46/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1837 - accuracy: 0.9960 - val_loss: 0.6111 - val_accuracy: 0.9665
# Epoch 47/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0731 - accuracy: 0.9964 - val_loss: 0.8169 - val_accuracy: 0.9595
# Epoch 48/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0419 - accuracy: 0.9964 - val_loss: 0.6274 - val_accuracy: 0.9700
# Epoch 49/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0172 - accuracy: 0.9985 - val_loss: 5.0181 - val_accuracy: 0.8270
# Epoch 50/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0641 - accuracy: 0.9958 - val_loss: 0.4941 - val_accuracy: 0.9715
# Epoch 51/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0806 - accuracy: 0.9973 - val_loss: 0.7516 - val_accuracy: 0.9630
# Epoch 52/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0212 - accuracy: 0.9981 - val_loss: 1.9416 - val_accuracy: 0.9395
# Epoch 53/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0431 - accuracy: 0.9980 - val_loss: 0.5301 - val_accuracy: 0.9710
# Epoch 54/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0322 - accuracy: 0.9977 - val_loss: 0.9506 - val_accuracy: 0.9265
# Epoch 55/100
# 250/250 [==============================] - 11s 42ms/step - loss: 0.0374 - accuracy: 0.9980 - val_loss: 1.2071 - val_accuracy: 0.9530
# Epoch 56/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0919 - accuracy: 0.9969 - val_loss: 0.7439 - val_accuracy: 0.9655
# Epoch 57/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0197 - accuracy: 0.9984 - val_loss: 0.7911 - val_accuracy: 0.9620
# Epoch 58/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0475 - accuracy: 0.9980 - val_loss: 0.8855 - val_accuracy: 0.9610
# Epoch 59/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0255 - accuracy: 0.9979 - val_loss: 1.4011 - val_accuracy: 0.9535
# Epoch 60/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0123 - accuracy: 0.9987 - val_loss: 0.7208 - val_accuracy: 0.9700
# Epoch 61/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0572 - accuracy: 0.9961 - val_loss: 2.9025 - val_accuracy: 0.9080
# Epoch 62/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0516 - accuracy: 0.9969 - val_loss: 0.6716 - val_accuracy: 0.9655
# Epoch 63/100
# 250/250 [==============================] - 11s 43ms/step - loss: 5.1953e-06 - accuracy: 1.0000 - val_loss: 0.7075 - val_accuracy: 0.9655
# Epoch 64/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1326 - accuracy: 0.9956 - val_loss: 0.9619 - val_accuracy: 0.9635
# Epoch 65/100
# 250/250 [==============================] - 11s 43ms/step - loss: 2.2984e-07 - accuracy: 1.0000 - val_loss: 0.8174 - val_accuracy: 0.9635
# Epoch 66/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0631 - accuracy: 0.9971 - val_loss: 0.7029 - val_accuracy: 0.9715
# Epoch 67/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0715 - accuracy: 0.9971 - val_loss: 0.8407 - val_accuracy: 0.9650
# Epoch 68/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0901 - accuracy: 0.9952 - val_loss: 0.7746 - val_accuracy: 0.9710
# Epoch 69/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0648 - accuracy: 0.9976 - val_loss: 0.7777 - val_accuracy: 0.9695
# Epoch 70/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0523 - accuracy: 0.9983 - val_loss: 0.7241 - val_accuracy: 0.9705
# Epoch 71/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0249 - accuracy: 0.9990 - val_loss: 0.6589 - val_accuracy: 0.9705
# Epoch 72/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0358 - accuracy: 0.9984 - val_loss: 0.7472 - val_accuracy: 0.9615
# Epoch 73/100
# 250/250 [==============================] - 11s 42ms/step - loss: 0.0424 - accuracy: 0.9976 - val_loss: 0.9370 - val_accuracy: 0.9685
# Epoch 74/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0372 - accuracy: 0.9990 - val_loss: 0.6913 - val_accuracy: 0.9630
# Epoch 75/100
# 250/250 [==============================] - 11s 43ms/step - loss: 1.4648e-08 - accuracy: 1.0000 - val_loss: 1.7548 - val_accuracy: 0.9335
# Epoch 76/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.1584 - accuracy: 0.9960 - val_loss: 0.5998 - val_accuracy: 0.9715
# Epoch 77/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0963 - accuracy: 0.9977 - val_loss: 0.8749 - val_accuracy: 0.9665
# Epoch 78/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0175 - accuracy: 0.9994 - val_loss: 1.0420 - val_accuracy: 0.9575
# Epoch 79/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0757 - accuracy: 0.9980 - val_loss: 0.7325 - val_accuracy: 0.9650
# Epoch 80/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0582 - accuracy: 0.9973 - val_loss: 0.8072 - val_accuracy: 0.9630
# Epoch 81/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0615 - accuracy: 0.9964 - val_loss: 0.9932 - val_accuracy: 0.9695
# Epoch 82/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.7302 - val_accuracy: 0.9725
# Epoch 83/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0562 - accuracy: 0.9980 - val_loss: 0.9903 - val_accuracy: 0.9650
# Epoch 84/100
# 250/250 [==============================] - 11s 43ms/step - loss: 4.6789e-09 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.9660
# Epoch 85/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0823 - accuracy: 0.9983 - val_loss: 0.8008 - val_accuracy: 0.9645
# Epoch 86/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0555 - accuracy: 0.9975 - val_loss: 0.8792 - val_accuracy: 0.9695
# Epoch 87/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0062 - accuracy: 0.9995 - val_loss: 0.8592 - val_accuracy: 0.9740
# Epoch 88/100
# 250/250 [==============================] - 11s 42ms/step - loss: 1.5907e-05 - accuracy: 1.0000 - val_loss: 0.8781 - val_accuracy: 0.9675
# Epoch 89/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0274 - accuracy: 0.9991 - val_loss: 0.8417 - val_accuracy: 0.9650
# Epoch 90/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.8283 - val_accuracy: 0.9700
# Epoch 91/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0085 - accuracy: 0.9994 - val_loss: 1.0586 - val_accuracy: 0.9635
# Epoch 92/100
# 250/250 [==============================] - 11s 43ms/step - loss: 2.2501e-09 - accuracy: 1.0000 - val_loss: 1.1477 - val_accuracy: 0.9680
# Epoch 93/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0089 - accuracy: 0.9994 - val_loss: 0.9334 - val_accuracy: 0.9730
# Epoch 94/100
# 250/250 [==============================] - 11s 43ms/step - loss: 1.2065e-04 - accuracy: 0.9999 - val_loss: 2.2423 - val_accuracy: 0.9440
# Epoch 95/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0730 - accuracy: 0.9970 - val_loss: 0.6097 - val_accuracy: 0.9685
# Epoch 96/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0202 - accuracy: 0.9990 - val_loss: 0.8824 - val_accuracy: 0.9705
# Epoch 97/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0191 - accuracy: 0.9990 - val_loss: 1.1878 - val_accuracy: 0.9640
# Epoch 98/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 1.1030 - val_accuracy: 0.9695
# Epoch 99/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0047 - accuracy: 0.9999 - val_loss: 1.8234 - val_accuracy: 0.9495
# Epoch 100/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.0257 - accuracy: 0.9990 - val_loss: 0.9893 - val_accuracy: 0.9665

# %%
def plotmodelhistory(history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

print(history.history.keys())

plotmodelhistory(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# make prediction.
pred = model.predict(x_test)
# Out:
# 63/63 [==============================] - 1s 12ms/step - loss: 0.9893 - accuracy: 0.9665
# Test loss: 0.9892764091491699
# Test accuracy: 0.9664999842643738
# 63/63 [==============================] - 1s 10ms/step

# %%
def heatmap(data, row_labels, col_labels, ax=None, cbar_kw={}, cbarlabel="", **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.
    """
    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)
    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)

    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')

    return im, cbar

def annotate_heatmap(im, data=None, fmt="d", threshold=None):
    """
    A function to annotate a heatmap.
    """
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            text = im.axes.text(j, i, format(data[i, j], fmt), horizontalalignment="center",
                                 color="black" if data[i, j] > thresh else "black")
            texts.append(text)

    return texts

# %%
labels = ['pothole','normal']

# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test, axis=1)
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = pred[errors]
Y_true_errors = Y_true[errors]
X_test_errors = x_test[errors]

cm = confusion_matrix(Y_true, Y_pred_classes)
thresh = cm.max() / 2.

fig, ax = plt.subplots(figsize=(12,12))
im, cbar = heatmap(cm, labels, labels, ax=ax,
                   cmap=plt.cm.Blues, cbarlabel="count of predictions")
texts = annotate_heatmap(im, data=cm, threshold=thresh)

fig.tight_layout()
plt.show()

# %%
print(classification_report(Y_true, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1000
#            1       0.97      0.96      0.97      1000
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000

# %%
R = 5
C = 5
fig, axes = plt.subplots(R, C, figsize=(12,12))
axes = axes.ravel()

for i in np.arange(0, R*C):
    axes[i].imshow(x_test[i])
    axes[i].set_title("True: %s \nPredict: %s" % (labels[Y_true[i]], labels[Y_pred_classes[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %%
R = 3
C = 5
fig, axes = plt.subplots(R, C, figsize=(12,8))
axes = axes.ravel()

misclassified_idx = np.where(Y_pred_classes != Y_true)[0]
for i in np.arange(0, R*C):
    axes[i].imshow(x_test[misclassified_idx[i]])
    axes[i].set_title("True: %s \nPredicted: %s" % (labels[Y_true[misclassified_idx[i]]],
                                                  labels[Y_pred_classes[misclassified_idx[i]]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)
