# %%
# !pip install tensorflow-addons
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import zipfile
from PIL import Image
from tensorflow.keras.utils import to_categorical

# Define the path to your zip file containing the dataset
zip_file_path = '/content/drive/MyDrive/CSE400 Thesis/Pothole Dataset 10000.zip'

# Define the directory where you want to extract the dataset
extracted_path = '/Downloads/FINAL_DATASET_TT'

# Create the directory for extracted data
os.makedirs(extracted_path, exist_ok=True)

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

# %%
train_path = "/Downloads/FINAL_DATASET_TT/train"
test_path = "/Downloads/FINAL_DATASET_TT/test"
x_train=[]

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 2
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
# !pip install -U -q tensorflow-addons
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.05
batch_size = 32
num_epochs = 100
image_size = 128

# %%
num_classes  = 2
input_shape  = (128, 128, 3)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (8000, 128, 128, 3) - y_train shape: (8000, 2)
# x_test shape: (2000, 128, 128, 3) - y_test shape: (2000, 2)

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_n = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
    ],
    name="data",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    data = data_n(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(data)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(
            from_logits=True, label_smoothing=0.1
        ),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "./tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Epoch 1/100
# 225/225 [==============================] - 55s 234ms/step - loss: 0.6282 - accuracy: 0.6942 - top-5-accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.8838 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 225/225 [==============================] - 50s 221ms/step - loss: 0.4160 - accuracy: 0.8649 - top-5-accuracy: 1.0000 - val_loss: 0.5956 - val_accuracy: 0.7362 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.3724 - accuracy: 0.8943 - top-5-accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.8637 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.3422 - accuracy: 0.9157 - top-5-accuracy: 1.0000 - val_loss: 0.3686 - val_accuracy: 0.8950 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.3356 - accuracy: 0.9192 - top-5-accuracy: 1.0000 - val_loss: 0.3371 - val_accuracy: 0.9100 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.3197 - accuracy: 0.9276 - top-5-accuracy: 1.0000 - val_loss: 0.3009 - val_accuracy: 0.9325 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 225/225 [==============================] - 51s 227ms/step - loss: 0.3189 - accuracy: 0.9292 - top-5-accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9588 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.3152 - accuracy: 0.9311 - top-5-accuracy: 1.0000 - val_loss: 0.3760 - val_accuracy: 0.9062 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.3057 - accuracy: 0.9400 - top-5-accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9438 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 225/225 [==============================] - 51s 227ms/step - loss: 0.2989 - accuracy: 0.9439 - top-5-accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9438 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.3042 - accuracy: 0.9392 - top-5-accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9600 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2873 - accuracy: 0.9518 - top-5-accuracy: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.8737 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2917 - accuracy: 0.9450 - top-5-accuracy: 1.0000 - val_loss: 0.2720 - val_accuracy: 0.9625 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2826 - accuracy: 0.9513 - top-5-accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9362 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2852 - accuracy: 0.9510 - top-5-accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9663 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2978 - accuracy: 0.9410 - top-5-accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9588 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2757 - accuracy: 0.9539 - top-5-accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2739 - accuracy: 0.9576 - top-5-accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9225 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2784 - accuracy: 0.9526 - top-5-accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8750 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2712 - accuracy: 0.9589 - top-5-accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9613 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2632 - accuracy: 0.9639 - top-5-accuracy: 1.0000 - val_loss: 0.3760 - val_accuracy: 0.9025 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2681 - accuracy: 0.9590 - top-5-accuracy: 1.0000 - val_loss: 0.2846 - val_accuracy: 0.9488 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2742 - accuracy: 0.9551 - top-5-accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2723 - accuracy: 0.9593 - top-5-accuracy: 1.0000 - val_loss: 0.3817 - val_accuracy: 0.8825 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2652 - accuracy: 0.9647 - top-5-accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9262 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2618 - accuracy: 0.9638 - top-5-accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 0.9550 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2601 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9262 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2653 - accuracy: 0.9624 - top-5-accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.9550 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2585 - accuracy: 0.9676 - top-5-accuracy: 1.0000 - val_loss: 0.2918 - val_accuracy: 0.9563 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2644 - accuracy: 0.9633 - top-5-accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9675 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 225/225 [==============================] - 50s 224ms/step - loss: 0.2632 - accuracy: 0.9646 - top-5-accuracy: 1.0000 - val_loss: 0.2367 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2562 - accuracy: 0.9682 - top-5-accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9438 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2548 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2660 - accuracy: 0.9632 - top-5-accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9538 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2597 - accuracy: 0.9668 - top-5-accuracy: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2501 - accuracy: 0.9715 - top-5-accuracy: 1.0000 - val_loss: 0.2684 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2611 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9187 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2567 - accuracy: 0.9686 - top-5-accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9237 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2544 - accuracy: 0.9706 - top-5-accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9237 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2454 - accuracy: 0.9746 - top-5-accuracy: 1.0000 - val_loss: 0.2961 - val_accuracy: 0.9550 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2525 - accuracy: 0.9715 - top-5-accuracy: 1.0000 - val_loss: 0.4301 - val_accuracy: 0.8763 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2470 - accuracy: 0.9728 - top-5-accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9438 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2461 - accuracy: 0.9747 - top-5-accuracy: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.9550 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2445 - accuracy: 0.9754 - top-5-accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9388 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2599 - accuracy: 0.9632 - top-5-accuracy: 1.0000 - val_loss: 0.2506 - val_accuracy: 0.9762 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2518 - accuracy: 0.9694 - top-5-accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.9050 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2464 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2580 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.9337 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2386 - accuracy: 0.9794 - top-5-accuracy: 1.0000 - val_loss: 0.2369 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2382 - accuracy: 0.9776 - top-5-accuracy: 1.0000 - val_loss: 0.2917 - val_accuracy: 0.9563 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2495 - accuracy: 0.9715 - top-5-accuracy: 1.0000 - val_loss: 0.3705 - val_accuracy: 0.9112 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2455 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.3517 - val_accuracy: 0.9200 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2449 - accuracy: 0.9744 - top-5-accuracy: 1.0000 - val_loss: 0.3261 - val_accuracy: 0.9375 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2405 - accuracy: 0.9762 - top-5-accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.9087 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2528 - accuracy: 0.9697 - top-5-accuracy: 1.0000 - val_loss: 0.3670 - val_accuracy: 0.9100 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2584 - accuracy: 0.9651 - top-5-accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9600 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2392 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9675 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2405 - accuracy: 0.9775 - top-5-accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2405 - accuracy: 0.9775 - top-5-accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9475 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2352 - accuracy: 0.9804 - top-5-accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9525 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2337 - accuracy: 0.9815 - top-5-accuracy: 1.0000 - val_loss: 0.3106 - val_accuracy: 0.9500 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2533 - accuracy: 0.9694 - top-5-accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9675 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2495 - accuracy: 0.9703 - top-5-accuracy: 1.0000 - val_loss: 0.2963 - val_accuracy: 0.9550 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2450 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.2688 - val_accuracy: 0.9712 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2412 - accuracy: 0.9779 - top-5-accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9475 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2361 - accuracy: 0.9803 - top-5-accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9362 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2312 - accuracy: 0.9817 - top-5-accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2343 - accuracy: 0.9824 - top-5-accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9600 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2383 - accuracy: 0.9792 - top-5-accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.9588 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2413 - accuracy: 0.9757 - top-5-accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 0.9500 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2371 - accuracy: 0.9807 - top-5-accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2319 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.9500 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2455 - accuracy: 0.9725 - top-5-accuracy: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9513 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2367 - accuracy: 0.9794 - top-5-accuracy: 1.0000 - val_loss: 0.3177 - val_accuracy: 0.9475 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2372 - accuracy: 0.9789 - top-5-accuracy: 1.0000 - val_loss: 0.2859 - val_accuracy: 0.9613 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2306 - accuracy: 0.9833 - top-5-accuracy: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9613 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2299 - accuracy: 0.9828 - top-5-accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2429 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9613 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2416 - accuracy: 0.9776 - top-5-accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2392 - accuracy: 0.9785 - top-5-accuracy: 1.0000 - val_loss: 0.2820 - val_accuracy: 0.9563 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 225/225 [==============================] - 50s 222ms/step - loss: 0.2301 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.3491 - val_accuracy: 0.9262 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2273 - accuracy: 0.9853 - top-5-accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 225/225 [==============================] - 51s 226ms/step - loss: 0.2342 - accuracy: 0.9807 - top-5-accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9463 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2361 - accuracy: 0.9796 - top-5-accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9625 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2351 - accuracy: 0.9786 - top-5-accuracy: 1.0000 - val_loss: 0.3136 - val_accuracy: 0.9425 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 225/225 [==============================] - 50s 221ms/step - loss: 0.2336 - accuracy: 0.9799 - top-5-accuracy: 1.0000 - val_loss: 0.2998 - val_accuracy: 0.9450 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 225/225 [==============================] - 51s 225ms/step - loss: 0.2343 - accuracy: 0.9797 - top-5-accuracy: 1.0000 - val_loss: 0.2999 - val_accuracy: 0.9500 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 225/225 [==============================] - 50s 224ms/step - loss: 0.2335 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9650 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 225/225 [==============================] - 50s 220ms/step - loss: 0.2366 - accuracy: 0.9781 - top-5-accuracy: 1.0000 - val_loss: 0.3290 - val_accuracy: 0.9262 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 225/225 [==============================] - 50s 224ms/step - loss: 0.2369 - accuracy: 0.9778 - top-5-accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9513 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2309 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9625 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 225/225 [==============================] - 49s 220ms/step - loss: 0.2274 - accuracy: 0.9844 - top-5-accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9500 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 225/225 [==============================] - 49s 220ms/step - loss: 0.2346 - accuracy: 0.9806 - top-5-accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9525 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2386 - accuracy: 0.9781 - top-5-accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 225/225 [==============================] - 49s 220ms/step - loss: 0.2324 - accuracy: 0.9817 - top-5-accuracy: 1.0000 - val_loss: 0.2759 - val_accuracy: 0.9625 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2384 - accuracy: 0.9779 - top-5-accuracy: 1.0000 - val_loss: 0.2541 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2280 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9663 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2222 - accuracy: 0.9878 - top-5-accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9663 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2430 - accuracy: 0.9757 - top-5-accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9675 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2291 - accuracy: 0.9842 - top-5-accuracy: 1.0000 - val_loss: 0.2915 - val_accuracy: 0.9513 - val_top-5-accuracy: 1.0000
# 63/63 [==============================] - 5s 72ms/step - loss: 0.2998 - accuracy: 0.9460 - top-5-accuracy: 1.0000
# Test accuracy: 94.6%
# Test top 5 accuracy: 100.0%

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
mpl.rcParams["figure.dpi"] = 300
plt.legend(['Train', 'Validation'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
# plt.figure(1)
# import matplotlib as mpl
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Model Accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# mpl.rcParams["figure.dpi"] = 300
# plt.legend(['Train', 'Test'], loc='upper left')
# mpl.rcParams["font.serif"] = "Times New Roman"
# mpl.rcParams['font.family'] = "Times New Roman"
# plt.grid()
# plt.show()
plt.figure(1)
import matplotlib as mpl
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
mpl.rcParams["figure.dpi"] = 300
plt.legend(['Train', 'Validation'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
# p = Augmentor.Pipeline("3D Objects/raw/",output_directory="../New_folder")
# #Step 3 Define the Operations
# p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
# p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
# p.sample(800)

import pathlib
import tensorflow as tf


data_dir = pathlib.Path('/Downloads/FINAL_DATASET_TT/train')

img_height=128
img_width=128


train_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 6400 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)

normalization_layer = tf.keras.layers.Rescaling(1./255)


import numpy as np
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 1600 files for validation.
# 0.04509804 0.959804

# %%
train_label = np.concatenate([y for x, y in train_ds], axis=0)
print(train_label.shape)

test_label = np.concatenate([y for x, y in val_ds], axis=0)
print(test_label.shape)
# Out:
# (6400,)
# (1600,)

# %%
import scipy
# if this works
from scipy.sparse import issparse

# %%
# !pip install scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
#Confution Matrix and Classification Report
import matplotlib.pyplot as plt
Y_pred = cct_model.predict_generator(val_ds, 1400)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_label, y_pred)
print(cm)
print('Classification Report')
target_names = ['normal', 'pothole']
print(classification_report(test_label, y_pred, target_names=target_names))
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# <ipython-input-72-81f4ada31f3c>:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = cct_model.predict_generator(val_ds, 1400)
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1400 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[ 41 779]
#  [524 256]]
# Classification Report
#               precision    recall  f1-score   support
#
#       normal       0.07      0.05      0.06       820
#      pothole       0.25      0.33      0.28       780
#
#     accuracy                           0.19      1600
#    macro avg       0.16      0.19      0.17      1600
# weighted avg       0.16      0.19      0.17      1600

# %%
# !pip install seaborn
# import seaborn as sns
# sns.set(font_scale=1.0)
# ax=sns.heatmap(cm, annot=True, cmap='summer', cbar=False, linewidths=3, linecolor='r', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
# #sns.heatmap(cm, annot=True,annot_kws={"size": 22})
# import matplotlib as mpl
# mpl.rcParams["figure.dpi"] = 300
# mpl.rcParams["font.serif"] = "Times New Roman"
# mpl.rcParams['font.family'] = "Times New Roman"
# sns.set(font_scale = 2.0)
# ax.set_xlabel('\nActual Values')
# ax.set_ylabel('Predicted Values ');
# !pip install seaborn
import seaborn as sns
ax=sns.heatmap(cm, annot=True, cmap='YlGn', cbar=False, linewidths=2, linecolor='y', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
#sns.heatmap(cm, annot=True,annot_kws={"size": 22})
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 300
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
# ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nActual Values')
ax.set_ylabel('Predicted Values ');
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
cct_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  data (Sequential)           (None, 128, 128, 3)          0         ['input_3[0][0]']
#
#  cct_tokenizer_2 (CCTTokeni  (None, 1024, 128)            75456     ['data[0][0]']
#  zer)
#
#  tf.__operators__.add_2 (TF  (None, 1024, 128)            0         ['cct_tokenizer_2[0][0]']
#  OpLambda)
#
#  layer_normalization_10 (La  (None, 1024, 128)            256       ['tf.__operators__.add_2[0][0]
#  yerNormalization)                                                  ']
#
#  multi_head_attention_4 (Mu  (None, 1024, 128)            131968    ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  stochastic_depth_8 (Stocha  (None, 1024, 128)            0         ['multi_head_attention_4[0][0]
#  sticDepth)                                                         ']
#
#  add_8 (Add)                 (None, 1024, 128)            0         ['stochastic_depth_8[0][0]',
#                                                                      'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  layer_normalization_11 (La  (None, 1024, 128)            256       ['add_8[0][0]']
#  yerNormalization)
#
#  dense_12 (Dense)            (None, 1024, 128)            16512     ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 1024, 128)            0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 1024, 128)            16512     ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024, 128)            0         ['dense_13[0][0]']
#
#  stochastic_depth_9 (Stocha  (None, 1024, 128)            0         ['dropout_9[0][0]']
#  sticDepth)
#
#  add_9 (Add)                 (None, 1024, 128)            0         ['stochastic_depth_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_12 (La  (None, 1024, 128)            256       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 1024, 128)            131968    ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  stochastic_depth_10 (Stoch  (None, 1024, 128)            0         ['multi_head_attention_5[0][0]
#  asticDepth)                                                        ']
#
#  add_10 (Add)                (None, 1024, 128)            0         ['stochastic_depth_10[0][0]',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_13 (La  (None, 1024, 128)            256       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_14 (Dense)            (None, 1024, 128)            16512     ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 1024, 128)            0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 1024, 128)            16512     ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 1024, 128)            0         ['dense_15[0][0]']
#
#  stochastic_depth_11 (Stoch  (None, 1024, 128)            0         ['dropout_11[0][0]']
#  asticDepth)
#
#  add_11 (Add)                (None, 1024, 128)            0         ['stochastic_depth_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_14 (La  (None, 1024, 128)            256       ['add_11[0][0]']
#  yerNormalization)
#
#  dense_16 (Dense)            (None, 1024, 1)              129       ['layer_normalization_14[0][0]
#                                                                     ']
#
#  tf.nn.softmax_2 (TFOpLambd  (None, 1024, 1)              0         ['dense_16[0][0]']
#  a)
#
#  tf.linalg.matmul_2 (TFOpLa  (None, 1, 128)               0         ['tf.nn.softmax_2[0][0]',
#  mbda)                                                               'layer_normalization_14[0][0]
#                                                                     ']
#
#  tf.compat.v1.squeeze_2 (TF  (None, 128)                  0         ['tf.linalg.matmul_2[0][0]']
#  OpLambda)
#
#  dense_17 (Dense)            (None, 2)                    258       ['tf.compat.v1.squeeze_2[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 407107 (1.55 MB)
# Trainable params: 407107 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
